# %% [markdown]
# # 🐍 Python Basics - Quick Hands-on Guide
#
# Welcome! This notebook introduces core Python concepts with short explanations and code examples. Try modifying and running the code cells to experiment.

# %% [markdown]
# ## I. Hello Python

# %% [markdown]
# ### 1. Variables and Data Types
#
# Variables store data. Python automatically infers the type.

# %%
# Assigning values
name = "Alice"
age = 25
height = 173.7
is_student = True

# Displaying variable values
print("Name:", name)
print("Age:", age)
print("Height:", height,  "cm")
print("Are they a student?", is_student)

# %%
# this is a comment. Python igoners this line but humans love them when they read someone else's code.
# name = Bob
# age = 28
# height = 162
# is_student = False
print("Name:", name)
print("Age:", age)
print("Height:", height,  "cm")
print("Are they a student?", is_student)

# %%
# Displaying types
print(type("Alice"))
print(type(name))

# %%
print(type(25))
print(type(age))

# %%
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))

# %% [markdown]
# ### 2. Basic Math Operations
#
# Python can do arithmetic like a calculator.

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Power:", a ** b)
print("Modulus:", a % b)

# %% [markdown]
# ### 3. Strings and Formatting
#
# Strings hold text. You can combine and format them easily.

# %%
first = "FAIR"
last = "Neuroscience"

# Concatenate
full = first + " " + last
print(full)

# %%
# f-string formatting
language = "Python"
birthyear = 1991
age = 2026 - birthyear
print(f"{language} is approximately {age} years old!")

# %%
import datetime

year = datetime.datetime.today().year
print(f"The year is {year}")

print(f"{language} is approximately {year - birthyear} years old!")

# %% [markdown]
# ### 4. Lists
#
# Lists hold ordered collections of items.

# %%
fruits = ["apple", "banana", "cherry"]
print(fruits[0])  # Access first item

# %%
# Add item of your choice
item = 72
fruits.append(item)
print(fruits)

# %% [markdown]
# ### 5. Conditions
#
# Use if/elif/else to make decisions.

# %%
score = 85

if score >= 90:
    print("Excellent!")
elif score >= 70:
    print("Good job!")
else:
    print("Keep practicing.")

# %% [markdown]
# ### HANDS ON
#
# A climbing gym in Stockholm gives a discount for students. They need a function to determine using `is_student` variable, whether a person gets a 20% discount or not.

# %%
discount = 20
# Your code here

# %%
# What if Alice does not know if they like climbing but open to trying if there is enough discount? Write some code that tells if Alice will try climbing.
discount = 20
discount_threshold = 30

# %% [markdown]
# ### 6. Loops
#
# Loops help repeat actions.

# %%
# For loop
for i in range(3):
    print("Looping:", i)

# While loop
n = 0
while n < 3:
    print("While Loop:", n)
    n += 1

# %% [markdown]
# ### 7. Functions
#
# Functions organize reusable blocks of code.

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Alice"))

# %% [markdown]
# ### HANDS ON
#
# Write a function called `greet_cheerfully` that takes a name and *prints*  a cheerful greeting

# %%
# Scribble some code below this line and greet your neighbor

# %% [markdown]
# ## II. Numpy
#
# What is NumPy?
#
# NumPy (Numerical Python) is the core library for efficient numerical computations in Python. It provides:
#
# Fast multi-dimensional arrays (ndarray)
#
# Mathematical operations on arrays
#
# Tools for linear algebra, statistics, random numbers, etc.

# %% [markdown]
# ### 1. Create Arrays

# %%
import numpy as np

# Create arrays
a = np.array([1, 2, 3])
b = np.array([[1, 2], [3, 4]])

print("1D:", a)
print("2D:\n", b)

# %%
arr = np.random.rand(3, 3)

print("Mean:", arr.mean())
print("Sum over axis 0:", arr.sum(axis=0))
print("Max value:", arr.max())

# %% [markdown]
# ### 2. Array Properties

# %%
print("Shape:", arr.shape)
print("Data type:", arr.dtype)
print("Size:", arr.size)

# %% [markdown]
# ### 3. Operations

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])

print("Addition:", x + y)
print("Element-wise multiply:", x * y)
print("Dot product:", np.dot(x, y))

# %% [markdown]
# ### 4. Useful Basic Functions

# %%
# np.array_equal
# np.ones
# np.zeros
# np.linalg.eigvals
# np.linalg.cross
# np.linalg.det
np.zeros_like?  # use question mark to read the documentation of a specific function/method/class

# %% [markdown]
# numpy documentation: https://numpy.org/doc/stable/

# %% [markdown]
# ## III. Plot using matplotlib
# What is Matplotlib?
#
# Matplotlib is a powerful library for creating static, animated, and interactive plots in Python.
#
# The pyplot module is often used like MATLAB's plotting functions.

# %%
import matplotlib.pyplot as plt

# Create data
x = np.linspace(0, 10, 100)
y = np.sin(x)
print(x)

# %%
# Plot
plt.plot(x, y, label='sin(x)')
plt.title("Simple Line Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.show()

# %%
sample_size = 150
num_of_boxes = 20
np.random.seed(7)  # OPTIONAL: seeds are used to reproduce random values. Using this seed, this box will look exactly the same for everyone
random_values = np.random.randn(sample_size, num_of_boxes)
plt.boxplot(random_values)
plt.title(f"Normally distrubuted random values. {sample_size} samples per box")
plt.show()

# TRY IT YOURSELF
# - increase/decrease sample size
# - Use a different seed with a neighbour and compare results

# %% [markdown]
# matplotlib documentation: https://matplotlib.org/

# %% [markdown]
# ## IV. Loading your Nifti volume
# What NiBabel does:
#
# Loads imaging data as NumPy arrays.
#
# Preserves affine transformations (for spatial orientation).
#
# Gives access to header information (e.g., voxel dimensions, TR).
#
# Saves modified images back to disk.

# %% [markdown]
# ### 1. Load you volume

# %%
import nibabel as nib

# Load a NIfTI image
img = nib.load("./workshops/ohbm-2023-example-input.nii.gz")
print(type(img))

# %% [markdown]
# ### 2. Niftis are arrays in the bakcground

# %%
# Get the image data as a NumPy array
arr = img.get_fdata()
arr

# %%
threshold = 0
plt.hist(
    arr[arr > threshold],
    bins=100
)

# %% [markdown]
# ### 3. Affines define transformation from one voxel space to another

# %%
# Check image shape
print("Shape:", arr.shape)
# Get the affine matrix
img.affine

# %% [markdown]
# ### 4. Creating A Mask
# (Several ways to do this. This way is chosen to demonstrate using arrays)

# %%
# create a mask from the image
threshold_value = 0.0010
masked_arr = np.zeros_like(arr)
masked_arr[arr > threshold_value] = 1
mask = nib.Nifti1Image(masked_arr, img.affine)
# nib.save(mask, 'mask.nii.gz')

# %% [markdown]
# nibabel documentation: https://nipy.org/nibabel/

# %% [markdown]
# ## V. Nilearn
# Nilearn is a powerful Python library for statistical analysis and visualization of neuroimaging data, especially for NIfTI, fMRI, and connectivity analyses. We will showcase:
# - Plotting brain images (e.g., fMRI, mask)
# - Plotting cortical surfaces

# %% [markdown]
# ### 1. Plotting NIfTI Images

# %%
from nilearn import plotting

# Plot anatomical background
plotting.plot_stat_map(img, cmap='magma')

# %%
plotting.plot_roi(mask)

# %% [markdown]
# ### 2. Loading Data from Nilearn

# %%
from nilearn import datasets, plotting

# Anatomical + functional image
fmri_data = datasets.fetch_development_fmri(n_subjects=1)
mni_anat = datasets.load_mni152_template()
func_img = nib.load(fmri_data.func[0])

# Plot anatomical image for MNI 152
plotting.plot_anat(mni_anat, title="Anatomical Image")

# %%
func_img.shape

# %%
# Plot the 3D volume
# plotting.plot_epi(func_img.slicer[:, :, :, 0], title="Single Volume from fMRI", cmap='magma')
plotting.view_img(func_img.slicer[:, :, :, 0], title="Single Volume from fMRI", cmap='magma', symmetric_cmap=False)

# %% [markdown]
# ### 3. Plotting Cortical Surfaces

# %%
# Example statistical map on surface
motor_task = datasets.fetch_neurovault_motor_task()
stat_map_img = motor_task["images"][0]
plotting.view_img_on_surf(stat_map_img, title=motor_task["images_meta"][0]["name"])

# %% [markdown]
# nilearn documentation: https://nilearn.github.io/stable/index.html

# %% [markdown]
# ## VI. Pandas DataFrame

# %% [markdown]
# ### 1. Load the Dataset

# %%
import seaborn as sns
import pandas as pd

# Load the penguins dataset
penguins = sns.load_dataset("penguins")

# Preview the first few rows
penguins.head()

# %% [markdown]
# ### 2. Basic Data Exploration

# %%
# Get general info
penguins.info()

# %%
# Summary stats for numerical columns
penguins.describe()

# %%
# Count missing values
penguins.isnull().sum()

# %% [markdown]
# ### 3. Plot Body Mass by Species

# %%
# Group by species and calculate average body mass
avg_mass = penguins.groupby("species")["body_mass_g"].mean()
avg_mass

# %%
# Plot using matplotlib
avg_mass.plot(kind="bar", color="skyblue")
plt.title("Average Body Mass by Penguin Species")
plt.ylabel("Body Mass (g)")
plt.xlabel("Species")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Box Plot by Species

# %%
penguins.plot(kind="box", by="species", figsize=(15,5))

# %% [markdown]
# ### 5. Scatter Plot by Species

# %%
# Drop rows with missing values for clean plotting
penguins_clean = penguins.dropna(subset=["flipper_length_mm", "body_mass_g"])

# Scatter plot: flipper length vs. body mass
for species in penguins_clean["species"].unique():
    subset = penguins_clean[penguins_clean["species"] == species]
    plt.scatter(subset["flipper_length_mm"], subset["body_mass_g"], label=species)

plt.xlabel("Flipper Length (mm)")
plt.ylabel("Body Mass (g)")
plt.title("Flipper Length vs Body Mass by Species")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# pandas documentation: https://pandas.pydata.org/
